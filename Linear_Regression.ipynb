# %% [markdown]
# # Linear Regression

# %%
1.) Linear Regression is a technique to model the relationship between two types of variables by fitting a linear equation.

# %%
variance(one variable)  -> co-variance(2 varibale direction) -> correlation(2 var direction+strength) -> Regression(direc+strength+how change in one variable attributes to change in another variable)

# %%
aim :- best fit line (where error is minimum)

# %%
ways to find out the error:-
i) Absolute error
ii) Squared error

# %%
error = sum of square residuals(SSR) = summation(y-y^)2

# %%
Algorithms 


1) ordinary least square(OLS) :- finding the best fit line
2) Gradient Descent :- step wise.
