# %% [markdown]
# # Data Preprocessing

# %%
# how to find the number of missing values?

isna().sum()
isnull().sum()

# %%
from sklearn.impute import SimpleImputer
import numpy as np
a= [[ 2 ,4 , np.nan],
   [np.nan , 3, 5]]
imputer = SimpleImputer(strategy = 'mean')
a_imputed = imputer.fit_transform(a)
print(a_imputed)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from sklearn.impute import SimpleImputer
#       2 import numpy as np
#       3 a= [[ 2 ,4 , np.nan],
#       4    [np.nan , 3, 5]]
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
from sklearn.impute import SimpleImputer
import numpy as np

# Create the data with missing values
a = [[2, 4, np.nan],
     [np.nan, 3, 5]]

# Create the imputer object with mean strategy
imputer = SimpleImputer(strategy='mean')

# Fit the imputer on data and transform it
a_imputed = imputer.fit_transform(a)

# Print the result
print(a_imputed)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from sklearn.impute import SimpleImputer
#       2 import numpy as np
#       4 # Create the data with missing values
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# !pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.7 MB 6.7 MB/s eta 0:00:02
#    --------- ------------------------------ 2.1/8.7 MB 6.2 MB/s eta 0:00:02
#    ------------ --------------------------- 2.6/8.7 MB 5.0 MB/s eta 0:00:02
#    --------------- ------------------------ 3.4/8.7 MB 4.5 MB/s eta 0:00:02
#    ------------------- -------------------- 4.2/8.7 MB 4.3 MB/s eta 0:00:02
#    --------------------- ------------------ 4.7/8.7 MB 4.3 MB/s eta 0:00:01
#    ------------------------- -------------- 5.5/8.7 MB 4.1 MB/s eta 0:00:01
#    --------------------------- ------------ 6.0/8.7 MB 4.0 MB/s eta 0:00:01
#    ------------------------------ --------- 6.6/8.7 MB 3.9 MB/s eta 0:00:01
#    -------------------------------- ------- 7.1/8.7 MB 3.5 MB/s eta 0:00:01
#    --------------------------------- ------ 7.3/8.7 MB 3.4 MB/s eta 0:00:01
# ...

# %%
from sklearn.impute import SimpleImputer
import numpy as np
a= [[ 2 ,4 , np.nan],
   [np.nan , 3, 5]]
imputer = SimpleImputer(strategy = 'mean')
a_imputed = imputer.fit_transform(a)
print(a_imputed)
# Out:
# [[2. 4. 5.]
#  [2. 3. 5.]]

# %%
# Standardize the data

a.) Standard scalar (z score method)  :- i)it is used to scaled the values up and down ii) it make the values unitless.

from sklearn.preprocessing import StandardScalar
std = StandardScalar()
std.fit_transform(df['Age','Salary'])

# %%
b) MinMax Scaling :-
MinMaxScaler scales (normalizes) the data to a fixed range, usually [0, 1].

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
data = np.array([[10, 20],
                 [15, 25],
                 [20, 30]])
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data)
print(scaled_data)
# Out:
# [[0.  0. ]
#  [0.5 0.5]
#  [1.  1. ]]

# %%
Encoding the data
a.) LabelEncoder
whenever dealing with categorial variables it need to get transformed into numerical values.
from sklearn.preprocessing import LabelEncoder
Le = LabelEncoder()
Le.fit_transform(categorialDf)

# %%
b.) One-hot encoding
One-Hot Encoding is another method to convert categorical variables into numbers, but unlike label encoding, it avoids implying any order.
from sklearn.preprocessing import OnehotEncoding
Ohe = OnehotEncoding()
Ohe.fit_transform(categorialDf)
