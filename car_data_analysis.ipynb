# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

import warnings 
warnings.filterwarnings('ignore')

# %%
car_data = pd.read_csv("car data.csv")

# %%
car_data.head(3)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0

# %%
# !pip install statsmodels
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
car_data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
# Bar plot between Selling_Price and Fuel_Type

sns.barplot(x='Fuel_Type', y='Selling_Price', data=car_data)
# Out:
# <Axes: xlabel='Fuel_Type', ylabel='Selling_Price'>

# %%
# Bar plot between Selling_Price and Seller_Type
sns.barplot(x = 'Seller_Type', y = 'Selling_Price', data = car_data)
# Out:
# <Axes: xlabel='Seller_Type', ylabel='Selling_Price'>

# %%
# Bar plot between Selling_Price and Transmission
sns.barplot(x = 'Transmission', y = 'Selling_Price', data = car_data)
# Out:
# <Axes: xlabel='Transmission', ylabel='Selling_Price'>

# %%
car_data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
# encoding values :- change values from categorial to numerical

car_data.replace({'Fuel_Type':{'Petrol':0,'Diesel':1, 'CNG':2}}, inplace = True)

# %%
car_data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000          0
# 1      sx4  2013           4.75           9.54       43000          1
# 2     ciaz  2017           7.25           9.85        6900          0
# 3  wagon r  2011           2.85           4.15        5200          0
# 4    swift  2014           4.60           6.87       42450          1
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
car_data.replace({'Transmission':{'Manual':0, 'Automatic':1}},inplace = True)

# %%
car_data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000          0
# 1      sx4  2013           4.75           9.54       43000          1
# 2     ciaz  2017           7.25           9.85        6900          0
# 3  wagon r  2011           2.85           4.15        5200          0
# 4    swift  2014           4.60           6.87       42450          1
#
#   Seller_Type  Transmission  Owner
# 0      Dealer             0      0
# 1      Dealer             0      0
# 2      Dealer             0      0
# 3      Dealer             0      0
# 4      Dealer             0      0

# %%
car_data.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 296     city  2016           9.50           11.6       33988          1
# 297     brio  2015           4.00            5.9       60000          0
# 298     city  2009           3.35           11.0       87934          0
# 299     city  2017          11.50           12.5        9000          1
# 300     brio  2016           5.30            5.9        5464          0
#
#     Seller_Type  Transmission  Owner
# 296      Dealer             0      0
# 297      Dealer             0      0
# 298      Dealer             0      0
# 299      Dealer             0      0
# 300      Dealer             0      0

# %%
car_data.tail(100)
# Out:
#       Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 201        i20  2010           3.25           6.79       58000          1
# 202  grand i10  2015           4.40           5.70       28200          0
# 203        i10  2011           2.95           4.60       53460          0
# 204        eon  2015           2.75           4.43       28282          0
# 205  grand i10  2016           5.25           5.70        3493          0
# ..         ...   ...            ...            ...         ...        ...
# 296       city  2016           9.50          11.60       33988          1
# 297       brio  2015           4.00           5.90       60000          0
# 298       city  2009           3.35          11.00       87934          0
# 299       city  2017          11.50          12.50        9000          1
# 300       brio  2016           5.30           5.90        5464          0
#
#     Seller_Type  Transmission  Owner
# 201      Dealer             0      1
# ...

# %%
car_data.tail(50)
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 251     city  2013           5.00           9.90       56701          0
# 252     brio  2015           5.40           6.82       31427          0
# 253     city  2014           7.20           9.90       48000          1
# 254     city  2013           5.25           9.90       54242          0
# 255     brio  2012           3.00           5.35       53675          0
# 256     city  2016          10.25          13.60       49562          0
# 257     city  2015           8.50          13.60       40324          0
# 258     city  2015           8.40          13.60       25000          0
# 259    amaze  2014           3.90           7.00       36054          0
# 260     city  2016           9.15          13.60       29223          0
# 261     brio  2016           5.50           5.97        5600          0
# 262    amaze  2015           4.00           5.80       40023          0
# ...

# %%
car_data.replace({'Seller_Type':{'Dealer':0, 'Individual':1}}, inplace = True)

# %%
car_data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000          0
# 1      sx4  2013           4.75           9.54       43000          1
# 2     ciaz  2017           7.25           9.85        6900          0
# 3  wagon r  2011           2.85           4.15        5200          0
# 4    swift  2014           4.60           6.87       42450          1
#
#    Seller_Type  Transmission  Owner
# 0            0             0      0
# 1            0             0      0
# 2            0             0      0
# 3            0             0      0
# 4            0             0      0

# %%
# Drop unwanted column and target
x= car_data.drop(['Selling_Price','Car_Name','Year'],axis = 1)  
y = car_data['Selling_Price']

# %%
x
# Out:
#      Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner
# 0             5.59       27000          0            0             0      0
# 1             9.54       43000          1            0             0      0
# 2             9.85        6900          0            0             0      0
# 3             4.15        5200          0            0             0      0
# 4             6.87       42450          1            0             0      0
# ..             ...         ...        ...          ...           ...    ...
# 296          11.60       33988          1            0             0      0
# 297           5.90       60000          0            0             0      0
# 298          11.00       87934          0            0             0      0
# 299          12.50        9000          1            0             0      0
# 300           5.90        5464          0            0             0      0
#
# [301 rows x 6 columns]

# %%
# Heatmap to show the correlation between the featured_columns
sns.heatmap(x.corr() , cmap = 'YlGnBu', annot = True)
plt.show()

# %%
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %% [markdown]
# # Linear Regression

# %%
# splitting the data into two halves training :- 70 and  testing :- 30
from sklearn.model_selection import train_test_split
x_train_lm,x_test_lm,y_train_lm,y_test_lm = train_test_split(x,y,train_size = 0.7,random_state = 6)

# %%
x_train_lm
# Out:
#      Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner
# 263           7.70       16002          0            0             0      0
# 268           5.80       19000          0            0             0      0
# 182           0.58       30000          0            1             0      0
# 116           1.47       33000          0            1             0      0
# 158           0.54        8600          0            1             0      0
# ..             ...         ...        ...          ...           ...    ...
# 1             9.54       43000          1            0             0      0
# 281           7.60       50456          0            0             0      0
# 106           3.45       16500          0            1             0      1
# 227           4.43       57000          0            0             0      0
# 201           6.79       58000          1            0             0      1
#
# [210 rows x 6 columns]

# %%
x_train_lm.head()
# Out:
#      Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner
# 263           7.70       16002          0            0             0      0
# 268           5.80       19000          0            0             0      0
# 182           0.58       30000          0            1             0      0
# 116           1.47       33000          0            1             0      0
# 158           0.54        8600          0            1             0      0

# %%
x_train_lm
# Out:
#      Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner
# 263           7.70       16002          0            0             0      0
# 268           5.80       19000          0            0             0      0
# 182           0.58       30000          0            1             0      0
# 116           1.47       33000          0            1             0      0
# 158           0.54        8600          0            1             0      0
# ..             ...         ...        ...          ...           ...    ...
# 1             9.54       43000          1            0             0      0
# 281           7.60       50456          0            0             0      0
# 106           3.45       16500          0            1             0      1
# 227           4.43       57000          0            0             0      0
# 201           6.79       58000          1            0             0      1
#
# [210 rows x 6 columns]

# %%
from sklearn.linear_model import LinearRegression
#instantiate and fit
lm2 = LinearRegression()
lm2.fit(x,y)

list(zip(feature_cols, lm2.coef_))
# Out:
# [('Present_Price', np.float64(0.43801525874980407)),
#  ('Kms_Driven', np.float64(-2.277490788411684e-05)),
#  ('Fuel_Type', np.float64(1.866197541145235)),
#  ('Seller_Type', np.float64(-1.2399703863165492)),
#  ('Transmission', np.float64(1.7761551202203225)),
#  ('Owner', np.float64(-1.262239888285984))]

# %%
print(lm2.intercept_)
# Out:
# 2.0197271375941828

# %%
print(lm2.coef_)
# Out:
# [ 4.38015259e-01 -2.27749079e-05  1.86619754e+00 -1.23997039e+00
#   1.77615512e+00 -1.26223989e+00]

# %%
# prediction
y_train_pred = lm2.predict(x_train_lm)
y_test_pred = lm2.predict(x_test_lm)

# %%
from sklearn.metrics import r2_score

# %%
print("R square score  :" ,r2_score(y_train_lm, y_train_pred))
# Out:
# R square score  : 0.852415269553724

# %%
print("R square score y_test :",r2_score(y_test_lm, y_test_pred))
# Out:
# R square score y_test : 0.812466487978379

# %%
# scatter plot 'Actual price' vs 'Predicted price'
plt.scatter(y_train_lm,y_train_pred)
plt.xlabel('Actual price')
plt.ylabel('Predicted price')
# Out:
# Text(0, 0.5, 'Predicted price')

# %%
#plotting the actual and predicted value

c = [i for i in range(1,len(y_train_lm)+1,1)]
plt.plot(c, y_train_lm, color='r', linestyle='-', label='Actual Values')
plt.plot(c, y_train_pred, color='g', linestyle='-', label='Predicted Values')
plt.xlabel('Actual price')
plt.ylabel('Predicted price')
plt.title('Prediction Using X_train')
plt.legend()
plt.show()

# %%
c = [i for i in range (1,len(y_test_lm)+1,1)]
plt.plot(c,y_test_lm,color='r',linestyle='-',label="Actual Values")
plt.plot(c,y_test_pred,color='g',linestyle='-',label="Predicted Values")
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Prediction using x_test')
plt.legend()
plt.show()

# %% [markdown]
# # Thank You
